# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pyflux as pf
from sklearn import gaussian_process
from sklearn.gaussian_process.kernels import Matern, WhiteKernel, ConstantKernel

# %%
tsla_org = pd.read_csv("tsla.csv", sep=",")

# %% [markdown]
# tsla = pd.DataFrame(np.diff(np.log(tsla_org['Adj Close']))[500:len(tsla_org['Adj Close'])-120])
# tsla.index = pd.to_datetime(tsla_org['Date'].values[1+500:len(tsla_org)-120])
# tsla.columns = ['AdjClose']
# plt.figure(figsize=(15,5))
# plt.plot(tsla)
# plt.ylabel('Tesla')
# plt.title('Tesla');

# %%
model = pf.GPNARX(data=tsla,ar=4, kernel=pf.SquaredExponential())
x = model.fit()
x.summary()

# %%
model.plot_fit(figsize=((15,10)))

# %%
model.plot_predict(h=8,past_values=200,figsize=(15,5))
